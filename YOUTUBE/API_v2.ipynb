# %%
import pandas as pd
import numpy as np
import json
import isodate 

# Data viz packages
import seaborn as sns # for visualisation 
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
from googleapiclient.discovery import build
from dateutil import parser

# %%
# api_key = 'AIzaSyB-4NIQtecQPbRX7TWKphThkb9_Brh2wL4'

# %%
from serpapi import GoogleSearch

# %%
# from serpapi import GoogleSearch

def fetch_videos(channel_username, api_key):
    params = {
        "engine": "youtube",
        "search_query": f"site:youtube.com/channel/ {channel_username}",
        "api_key" : api_key
    }
    search = GoogleSearch(params)
    results = search.get_dict()
    # video_results = results["video_results"]
    # return video_results

    print(results)  # Print the results dictionary for inspection
    video_results = results.get("video_results", [])  # Use .get() to handle KeyError
    return video_results

def main():
    # api_key = "YOUR_SERPAPI_API_KEY"  # Replace this with your actual SerpAPI key
    api_key = 'cb9e80b777f996a1f773a74c9cca18f4246e0952bf93e7d3823ebf28e39da493'
    channel_usernames = input("Enter channel usernames separated by commas: ").split(',')
    
    for channel_username in channel_usernames:
        videos = fetch_videos(channel_username.strip(), api_key)
        print(f"Videos for channel '{channel_username.strip()}':")
        for video in videos:
            print(video["title"], "-", video["link"])

if __name__ == "__main__":
    main()
# Out:
# {'search_metadata': {'id': '65f8cced9c449dd787653202', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/b83ca67c7f3eb197/65f8cced9c449dd787653202.json', 'created_at': '2024-03-18 23:23:25 UTC', 'processed_at': '2024-03-18 23:23:25 UTC', 'youtube_url': 'https://www.youtube.com/results?search_query=site%3Ayoutube.com%2Fchannel%2F+mkbhd', 'raw_html_file': 'https://serpapi.com/searches/b83ca67c7f3eb197/65f8cced9c449dd787653202.html', 'total_time_taken': 0.81}, 'search_parameters': {'engine': 'youtube', 'search_query': 'site:youtube.com/channel/ mkbhd'}, 'search_information': {'total_results': 2045, 'video_results_state': 'Results for exact spelling'}, 'channel_results': [{'position_on_page': 1, 'title': 'Auto Focus', 'link': 'https://www.youtube.com/@AutoFocus', 'subscribers': 883000, 'description': 'Car videos from MKBHD!', 'thumbnail': 'https://yt3.ggpht.com/lSwLKpd-BGsaDwVDNP_pgUcf4rg3akrE7p5FjAWzv3w4oR7bBkx22QhOc7ulHLQw6ZVTg-RE=s88-c-k-c0x00ffffff-no-rj-mo'}, {'pos
# ...
