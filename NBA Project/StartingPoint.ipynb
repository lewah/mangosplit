# %% [markdown]
# This project we will use the NBA API from this link https://github.com/swar/nba_api
# Install - pip install nba_api - through this the packages installed are: urllib3, numpy, idna, charset-normalizer, certifi, requests, nba_api

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/ingridlewah/Desktop/Projects/MANGODEV/mangosplit/NBA Project/StartingPoint.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/Users/ingridlewah/Desktop/Projects/MANGODEV/mangosplit/NBA%20Project/StartingPoint.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
from nba_api.stats.static import players

#players we want to look into
superstars = ["Stephen Curry", "Michael Jordan", "Kevin Durant",
             "Lebron James", "Allen Iverson"]

#initialize empty lists that will put player id into
player_ids = []
for i in superstars:
    player_ids.append(players.find_players_by_full_name(i)[0]['id'])
# print(player_ids)

# %%
players.find_players_by_full_name("Stephen Curry")
# Out:
# [{'id': 201939,
#   'full_name': 'Stephen Curry',
#   'first_name': 'Stephen',
#   'last_name': 'Curry',
#   'is_active': True}]

# %%
from nba_api.stats.endpoints import playergamelog
from nba_api.stats.library.parameters import SeasonAll
# import pandas as pd 

#pull game logs of each player
game_logs =[]
for i in player_ids:
    game_logs.append(playergamelog.PlayerGameLog(player_id=i, season = SeasonAll.all).get_data_frames()[0])

player_data = dict(zip(superstars, game_logs))

#Enter any player from superstar list to access their game log
# player_data["Lebron James"]
player_data["Stephen Curry"]
# Out:
#     SEASON_ID  Player_ID     Game_ID     GAME_DATE      MATCHUP WL  MIN  FGM  \
# 0       22023     201939  0022300176  NOV 11, 2023  GSW vs. CLE  L   33    9
# 1       22023     201939  0022300169  NOV 08, 2023    GSW @ DEN  L   34    6
# 2       22023     201939  0022300145  NOV 06, 2023    GSW @ DET  W   33   12
# 3       22023     201939  0022300142  NOV 05, 2023    GSW @ CLE  L   31    8
# 4       22023     201939  0022300005  NOV 03, 2023    GSW @ OKC  W   31    9
# ..        ...        ...         ...           ...          ... ..  ...  ...
# 887     22009     201939  0020900096  NOV 08, 2009    GSW @ SAC  L   31    4
# 888     22009     201939  0020900082  NOV 06, 2009  GSW vs. LAC  L   22    1
# 889     22009     201939  0020900069  NOV 04, 2009  GSW vs. MEM  W   28    3
# 890     22009     201939  0020900030  OCT 30, 2009    GSW @ PHX  L   39    5
# 891     22009     201939  0020900015  OCT 28, 2009  GSW vs. HOU  L   36    7
#
#      FGA  FG_PCT  ...  DREB  REB  AST  STL  BLK  TOV  PF  PTS  PLUS_MINUS  \
# 0     24   0.375  ...     2    3    2    1    1    4   1   30          -8
# 1     17   0.353  ...     4    5    4    1    0    3   2   23         -10
# 2     26   0.462  ...     2    2    4    0    0    3   1   34          17
# 3     16   0.500  ...     2    2    4    1    0    6   0   28          -6
# 4     15   0.600  ...     5    8    7    2    0    3   1   30           5
# ..   ...     ...  ...   ...  ...  ...  ...  ...  ...  ..  ...         ...
# 887    8   0.500  ...     3    4    6    0    0    5   4    9          -5
# 888    5   0.200  ...     1    1    3    0    0    0   6    5         -13
# 889    6   0.500  ...     5    5    9    2    0    1   4    7          -4
# 890    9   0.556  ...     2    2    4    1    0    3   5   12         -19
# 891   12   0.583  ...     1    2    7    4    0    2   2   14           7
#
#      VIDEO_AVAILABLE
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# ..               ...
# 887                0
# 888                0
# 889                0
# 890                0
# 891                0
#
# [892 rows x 27 columns]
