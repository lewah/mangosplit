# %%
# packages
import pandas as pd
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
netflix_data = pd.read_csv("dataset/cleaned_netflix_data.csv", index_col=0)
netflix_data
# Out:
#                                          title  \
# type
# Movie                     Dick Johnson Is Dead
# Movie                             The Starling
# TV Show                           On the Verge
# Movie                                 Stowaway
# Movie                                 Wild Dog
# ...                                        ...
# Movie                    This Lady Called Life
# Movie                                Vizontele
# Movie                               HOMUNCULUS
# TV Show  Life in Color with David Attenborough
# Movie                     Searching For Sheela
#
#                                  director  \
# type
# Movie                     Kirsten Johnson
# Movie                      Theodore Melfi
# TV Show                           Unknown
# Movie                           Joe Penna
# Movie                     Ahishor Solomon
# ...                                   ...
# Movie                        Kayode Kasum
# Movie    Yılmaz Erdoğan, Ömer Faruk Sorak
# Movie                     Takashi Shimizu
# TV Show                           Unknown
# Movie                             Unknown
#
#                                                       cast  \
# type
# Movie                                              Unknown
# Movie    Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# TV Show  Julie Delpy, Elisabeth Shue, Sarah Jones, Alex...
# Movie    Anna Kendrick, Toni Collette, Daniel Dae Kim, ...
# Movie    Nagarjuna Akkineni, Dia Mirza, Saiyami Kher, A...
# ...                                                    ...
# Movie    Bisola Aiyeola, Efa Iwara, Molawa Onajobi, Tin...
# Movie    Yılmaz Erdoğan, Demet Akbağ, Altan Erkekli, Ce...
# Movie    Go Ayano, Ryo Narita, Yukino Kishii, Anna Ishi...
# TV Show                                 David Attenborough
# Movie                                      Ma Anand Sheela
#
#                            country          date_added  release_year rating  \
# type
# Movie                United States  September 25, 2021          2020  PG-13
# Movie                United States  September 24, 2021          2021  PG-13
# TV Show      France, United States   September 7, 2021          2021  TV-MA
# Movie       Germany, United States      April 22, 2021          2021  TV-MA
# Movie                      Unknown      April 22, 2021          2020  TV-MA
# ...                            ...                 ...           ...    ...
# Movie                      Nigeria      April 23, 2021          2020  TV-14
# Movie                       Turkey      April 23, 2021          2001  TV-MA
# Movie                        Japan      April 22, 2021          2021  TV-MA
# TV Show  Australia, United Kingdom      April 22, 2021          2021  TV-PG
# Movie                        India      April 22, 2021          2021  TV-14
#
#          duration                                          listed_in  \
# type
# Movie      90 min                                      Documentaries
# Movie     104 min                                   Comedies, Dramas
# TV Show  1 Season                             TV Comedies, TV Dramas
# Movie     116 min            Dramas, International Movies, Thrillers
# Movie     126 min           Action & Adventure, International Movies
# ...           ...                                                ...
# Movie     120 min      Dramas, International Movies, Romantic Movies
# Movie     106 min             Comedies, Dramas, International Movies
# Movie     116 min     Horror Movies, International Movies, Thrillers
# TV Show  1 Season  British TV Shows, Docuseries, International TV...
# Movie      58 min                Documentaries, International Movies
#
#                                                description
# type
# Movie    As her father nears the end of his life, filmm...
# Movie    A woman adjusting to life after a loss contend...
# TV Show  Four women — a chef, a single mom, an heiress ...
# Movie    A three-person crew on a mission to Mars faces...
# Movie    A brash but brilliant Indian intelligence agen...
# ...                                                    ...
# Movie    Abandoned by her family, young single mother A...
# Movie    In 1974, a rural town in Anatolia gets its fir...
# Movie    Truth and illusion blurs when a homeless amnes...
# TV Show  Using innovative technology, this docuseries e...
# Movie    Journalists and fans await Ma Anand Sheela as ...
#
# [8807 rows x 10 columns]

# %%
netflix_data.isna().sum()
# Out:
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
# Shape of the dataset
netflix_data.shape
# Out:
# (8807, 10)

# %%
# check non unique values 
netflix_data.nunique()
# Out:
# title           8807
# director        4529
# cast            7693
# country          749
# date_added      1767
# release_year      74
# rating            14
# duration         220
# listed_in        514
# description     8775
# dtype: int64

# %%
# check for duplicate values
netflix_data.duplicated().sum()
# Out:
# 0

# %%
# understanding variables
variables = pd.DataFrame(columns=['Variable','Num of unique values','values'])

for i,var in enumerate(netflix_data.columns):
    variables.loc[i] = [var,netflix_data[var].nunique(),netflix_data[var].unique().tolist()]

variables
# Out:
#        Variable  Num of unique values  \
# 0         title                  8807
# 1      director                  4529
# 2          cast                  7693
# 3       country                   749
# 4    date_added                  1767
# 5  release_year                    74
# 6        rating                    14
# 7      duration                   220
# 8     listed_in                   514
# 9   description                  8775
#
#                                               values
# 0  [Dick Johnson Is Dead, The Starling, On the Ve...
# 1  [Kirsten Johnson, Theodore Melfi, Unknown, Joe...
# 2  [Unknown, Melissa McCarthy, Chris O'Dowd, Kevi...
# 3  [United States, France, United States, Germany...
# 4  [September 25, 2021, September 24, 2021, Septe...
# 5  [2020, 2021, 2015, 2013, 2018, 2017, 2019, 201...
# 6  [PG-13, TV-MA, TV-14, TV-Y, TV-Y7, R, PG, TV-P...
# 7  [90 min, 104 min, 1 Season, 116 min, 126 min, ...
# 8  [Documentaries, Comedies, Dramas, TV Comedies,...
# 9  [As her father nears the end of his life, film...
