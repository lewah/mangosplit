# %%
# packages
import pandas as pd

# %%
netflix_data = pd.read_csv("dataset/netflix_dataset.csv", index_col=0)
netflix_data
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                    ...            ...
# s8803    Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# s8804                                                  NaN            NaN
# s8805    Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# s8806    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# s8807    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# s2       September 24, 2021          2021  TV-MA  2 Seasons
# s3       September 24, 2021          2021  TV-MA   1 Season
# s4       September 24, 2021          2021  TV-MA   1 Season
# s5       September 24, 2021          2021  TV-MA  2 Seasons
# ...                     ...           ...    ...        ...
# s8803     November 20, 2019          2007      R    158 min
# s8804          July 1, 2019          2018  TV-Y7  2 Seasons
# s8805      November 1, 2019          2009      R     88 min
# s8806      January 11, 2020          2006     PG     88 min
# s8807         March 2, 2019          2015  TV-14    111 min
#
#                                                  listed_in  \
# show_id
# s1                                           Documentaries
# s2         International TV Shows, TV Dramas, TV Mysteries
# s3       Crime TV Shows, International TV Shows, TV Act...
# s4                                  Docuseries, Reality TV
# s5       International TV Shows, Romantic TV Shows, TV ...
# ...                                                    ...
# s8803                       Cult Movies, Dramas, Thrillers
# s8804               Kids' TV, Korean TV Shows, TV Comedies
# s8805                              Comedies, Horror Movies
# s8806                   Children & Family Movies, Comedies
# s8807       Dramas, International Movies, Music & Musicals
#
#                                                description
# show_id
# s1       As her father nears the end of his life, filmm...
# s2       After crossing paths at a party, a Cape Town t...
# s3       To protect his family from a powerful drug lor...
# s4       Feuds, flirtations and toilet talk go down amo...
# s5       In a city of coaching centers known to train I...
# ...                                                    ...
# s8803    A political cartoonist, a crime reporter and a...
# s8804    While living alone in a spooky town, a young g...
# s8805    Looking to survive in a world taken over by zo...
# s8806    Dragged from civilian life, a former superhero...
# s8807    A scrappy but poor boy worms his way into a ty...
#
# [8807 rows x 11 columns]

# %% [markdown]
# Exploring the data

# %%
# find out the data types in your data
netflix_data.dtypes
# Out:
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
# find out the columns of your dataset
netflix_data.columns
# Out:
# Index(['type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
# describe mean,min,max,25%, 50%, 75% etc
netflix_data.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
# Finding the number of NULL values in @ column
# finding if you have any missing values
netflix_data.isna().sum()
# Out:
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# Data cleaning
# -----
# 1. Duration
# ----

# %%
# find the number of non unique values 
netflix_data['director'].nunique()
# Out:
# 4528

# %%
# Find rows with missing 'duration'
null_rows_duration = netflix_data[netflix_data['duration'].isnull()]

# Define a custom function to swap 'duration' and 'rating'
def swap_duration_rating(row):
    if pd.isna(row['duration']):
        row['duration'], row['rating'] = row['rating'], row['duration']
    return row

# Apply the custom function to swap the values
null_rows_duration = null_rows_duration.apply(swap_duration_rating, axis=1)

# Add the swapped data back to the main DataFrame 'netflix_data'
netflix_data = netflix_data.combine_first(null_rows_duration)

# Now, the values should be swapped
# print(null_rows_duration)

# %%
netflix_data.isna().sum()
# Out:
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# 2. Cleaning Rating Column
# -----

# %%
# find unique values for rating 
list_rating = netflix_data['rating'].unique()
list_rating
# Out:
# array(['PG-13', 'TV-MA', 'TV-14', 'TV-Y', 'TV-Y7', 'R', 'PG', 'TV-PG',
#        'TV-G', 'G', 'NC-17', 'NR', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
# Count the values in the 
netflix_data['rating'].value_counts()
# Out:
# rating
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %%
# Null values in rating
netflix_data.loc[netflix_data['rating'].isnull()]
# Out:
#             type                                              title  \
# show_id
# s5990      Movie  13TH: A Conversation with Oprah Winfrey & Ava ...
# s6828    TV Show                  Gargantia on the Verdurous Planet
# s7313    TV Show                                       Little Lunch
# s7538      Movie                               My Honor Was Loyalty
#
#                 director                                               cast  \
# show_id
# s5990                NaN                        Oprah Winfrey, Ava DuVernay
# s6828                NaN  Kaito Ishikawa, Hisako Kanemoto, Ai Kayano, Ka...
# s7313                NaN  Flynn Curry, Olivia Deeble, Madison Lu, Oisín ...
# s7538    Alessandro Pepe  Leone Frisa, Paolo Vaccarino, Francesco Miglio...
#
#            country        date_added  release_year rating  duration  \
# show_id
# s5990          NaN  January 26, 2017          2017    NaN    37 min
# s6828        Japan  December 1, 2016          2013    NaN  1 Season
# s7313    Australia  February 1, 2018          2015    NaN  1 Season
# s7538        Italy     March 1, 2017          2015    NaN   115 min
#
#                                     listed_in  \
# show_id
# s5990                                  Movies
# s6828    Anime Series, International TV Shows
# s7313                   Kids' TV, TV Comedies
# s7538                                  Dramas
#
#                                                description
# show_id
# s5990    Oprah Winfrey sits down with director Ava DuVe...
# s6828    After falling through a wormhole, a space-dwel...
# s7313    Adopting a child's perspective, this show take...
# s7538    Amid the chaos and horror of World War II, a c...

# %%
# Find the row with the title "My Honor Was Loyalty" and set its "rating" to "PG-13"
netflix_data.loc[netflix_data['title'] == 'My Honor Was Loyalty', 'rating'] = 'PG-13'
netflix_data.loc[netflix_data['title'] == 'Little Lunch', 'rating'] = 'TV-MA'
netflix_data.loc[netflix_data['title'] == 'Gargantia on the Verdurous Planet', 'rating'] = 'TV-14'
netflix_data.loc[netflix_data['cast'] == 'Oprah Winfrey, Ava DuVernay', 'rating'] = 'PG'

# %%
netflix_data.loc[netflix_data['rating'].isnull()]
# Out:
# Empty DataFrame
# Columns: [type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
# filtering rating with values 74 84 66 min 
netflix_data.loc[netflix_data['rating'].isin(['74 min', '84 min', '66 min'])]

# replacing values in rating 
# netflix_data.loc[netflix_data['title'] == 'Louis C.K.: Live at the Comedy Store', 'rating'] = 'TV-MA'
# netflix_data.loc[netflix_data['title'] == 'Louis C.K.: Hilarious', 'rating'] = 'TV-MA'
# netflix_data.loc[netflix_data['title'] == 'Louis C.K. 2017', 'rating'] = 'TV-MA'
# Out:
# Empty DataFrame
# Columns: [type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
# check if column rating is sorted 
# netflix_data['rating'].unique()

# check the count of the values in the column rating
netflix_data['rating'].value_counts()
# Out:
# rating
# TV-MA       3211
# TV-14       2161
# TV-PG        862
# R            799
# PG-13        491
# TV-Y7        334
# TV-Y         307
# PG           289
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# Name: count, dtype: int64

# %% [markdown]
# 3. Cleaning Date Added
# ----

# %%
# netflix_data['date_added'].unique()
# netflix_data['date_added'].value_counts().sort_values(ascending=False)
netflix_data.loc[netflix_data['date_added'].isnull()]
# Out:
#             type                                        title director  \
# show_id
# s6067    TV Show  A Young Doctor's Notebook and Other Stories      NaN
# s6175    TV Show              Anthony Bourdain: Parts Unknown      NaN
# s6796    TV Show                                      Frasier      NaN
# s6807    TV Show                                      Friends      NaN
# s6902    TV Show                              Gunslinger Girl      NaN
# s7197    TV Show                                     Kikoriki      NaN
# s7255    TV Show                          La Familia P. Luche      NaN
# s7407    TV Show                                        Maron      NaN
# s7848    TV Show                                 Red vs. Blue      NaN
# s8183    TV Show                 The Adventures of Figaro Pho      NaN
#
#                                                       cast         country  \
# show_id
# s6067    Daniel Radcliffe, Jon Hamm, Adam Godley, Chris...  United Kingdom
# s6175                                     Anthony Bourdain   United States
# s6796    Kelsey Grammer, Jane Leeves, David Hyde Pierce...   United States
# s6807    Jennifer Aniston, Courteney Cox, Lisa Kudrow, ...   United States
# s6902    Yuuka Nanri, Kanako Mitsuhashi, Eri Sendai, Am...           Japan
# s7197                                        Igor Dmitriev             NaN
# s7255    Eugenio Derbez, Consuelo Duval, Luis Manuel Áv...   United States
# s7407    Marc Maron, Judd Hirsch, Josh Brener, Nora Zeh...   United States
# s7848    Burnie Burns, Jason Saldaña, Gustavo Sorola, G...   United States
# s8183    Luke Jurevicius, Craig Behenna, Charlotte Haml...       Australia
#
#         date_added  release_year rating    duration  \
# show_id
# s6067          NaN          2013  TV-MA   2 Seasons
# s6175          NaN          2018  TV-PG   5 Seasons
# s6796          NaN          2003  TV-PG  11 Seasons
# s6807          NaN          2003  TV-14  10 Seasons
# s6902          NaN          2008  TV-14   2 Seasons
# s7197          NaN          2010   TV-Y   2 Seasons
# s7255          NaN          2012  TV-14   3 Seasons
# s7407          NaN          2016  TV-MA   4 Seasons
# s7848          NaN          2015     NR  13 Seasons
# s8183          NaN          2015  TV-Y7   2 Seasons
#
#                                                  listed_in  \
# show_id
# s6067             British TV Shows, TV Comedies, TV Dramas
# s6175                                           Docuseries
# s6796                       Classic & Cult TV, TV Comedies
# s6807                       Classic & Cult TV, TV Comedies
# s6902                         Anime Series, Crime TV Shows
# s7197                                             Kids' TV
# s7255    International TV Shows, Spanish-Language TV Sh...
# s7407                                          TV Comedies
# s7848    TV Action & Adventure, TV Comedies, TV Sci-Fi ...
# s8183                                Kids' TV, TV Comedies
#
#                                                description
# show_id
# s6067    Set during the Russian Revolution, this comic ...
# s6175    This CNN original series has chef Anthony Bour...
# s6796    Frasier Crane is a snooty but lovable Seattle ...
# s6807    This hit sitcom follows the merry misadventure...
# s6902    On the surface, the Social Welfare Agency appe...
# s7197    A wacky rabbit and his gang of animal pals hav...
# s7255    This irreverent sitcom featues Ludovico, Feder...
# s7407    Marc Maron stars as Marc Maron, who interviews...
# s7848    This parody of first-person shooter games, mil...
# s8183    Imagine your worst fears, then multiply them: ...

# %%
# Replacing NAN values in 'date_added' to January 1, 2020
netflix_data["date_added"].fillna("January 1, 2020", inplace = True)

# %%
netflix_data.loc[netflix_data['date_added'].isnull()]
# Out:
# Empty DataFrame
# Columns: [type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# 4. Cleaning country
# ----

# %%
netflix_data.isna().sum()
# Out:
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added         0
# release_year       0
# rating             0
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
# netflix_data['country'].unique()
netflix_data['country'].value_counts().sort_values(ascending=False)
# netflix_data.loc[netflix_data['country'].isnull()]
# Out:
# country
# United States                                 2818
# India                                          972
# United Kingdom                                 419
# Japan                                          245
# South Korea                                    199
#                                               ...
# Russia, Spain                                    1
# Egypt, Austria, United States                    1
# France, Netherlands, South Africa, Finland       1
# United States, East Germany, West Germany        1
# United States, United Kingdom, New Zealand       1
# Name: count, Length: 748, dtype: int64

# %%
# country col fill NAN with unknown 
netflix_data['country'].fillna("Unknown", inplace=True)

# check for null values
netflix_data.loc[netflix_data['country'].isnull()]
# Out:
# Empty DataFrame
# Columns: [type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
#this code filters data based on the country 'United States' and the output is saved in a csv file 
output_filename = 'us_country_count.csv'

#
us_data = netflix_data[netflix_data['country'].str.contains('United States')]
# count_us = us_data['country'].value_counts()
count_us = us_data['country'].value_counts().reset_index()
count_us.columns = ['Country', 'Count']

count_us.to_csv(output_filename, index=False)

print(count_us)

# %%
# Filtering the df(netflix_data) on data containing 'United States'
netflix_data[netflix_data['country'].str.contains('United States')]

# %% [markdown]
# 5. Cleaning up Cast
# ----

# %%
netflix_data.isna().sum()
# Out:
# type               0
# title              0
# director        2634
# cast             825
# country            0
# date_added         0
# release_year       0
# rating             0
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
# checking for null values
netflix_data.loc[netflix_data['cast'].isnull()]
# netflix_data['cast'].sample(10)
# Out:
#             type                                     title  \
# show_id
# s1         Movie                      Dick Johnson Is Dead
# s1006      Movie        Keymon and Nani in Space Adventure
# s1012      Movie                              Free to Play
# s102       Movie                    Untold: Breaking Point
# s103     TV Show  Countdown: Inspiration4 Mission to Space
# ...          ...                                       ...
# s92        Movie                The Women and the Murderer
# s920     TV Show  The Sons of Sam: A Descent into Darkness
# s926     TV Show                        Angelina Ballerina
# s937     TV Show               Miniforce: Super Dino Power
# s958     TV Show                                 Pet Stars
#
#                                    director cast        country  \
# show_id
# s1                          Kirsten Johnson  NaN  United States
# s1006                                   NaN  NaN        Unknown
# s1012                                   NaN  NaN  United States
# s102               Chapman Way, Maclain Way  NaN  United States
# s103                            Jason Hehir  NaN        Unknown
# ...                                     ...  ...            ...
# s92      Mona Achache, Patricia Tourancheau  NaN         France
# s920                           Joshua Zeman  NaN  United States
# s926                                    NaN  NaN        Unknown
# s937                                    NaN  NaN        Unknown
# s958                                    NaN  NaN        Unknown
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# s1006        April 20, 2021          2013   TV-Y     76 min
# s1012        April 19, 2021          2014  TV-14     76 min
# s102      September 7, 2021          2021  TV-MA     80 min
# s103      September 6, 2021          2021  TV-14   1 Season
# ...                     ...           ...    ...        ...
# s92       September 9, 2021          2021  TV-14     92 min
# s920            May 5, 2021          2021  TV-MA   1 Season
# s926            May 1, 2021          2010   TV-Y  2 Seasons
# s937            May 1, 2021          2020  TV-Y7   1 Season
# s958         April 30, 2021          2021  TV-PG   1 Season
#
#                                    listed_in  \
# show_id
# s1                             Documentaries
# s1006     Children & Family Movies, Comedies
# s1012                          Documentaries
# s102            Documentaries, Sports Movies
# s103         Docuseries, Science & Nature TV
# ...                                      ...
# s92      Documentaries, International Movies
# s920              Crime TV Shows, Docuseries
# s926              British TV Shows, Kids' TV
# s937                                Kids' TV
# s958                              Reality TV
#
#                                                description
# show_id
# s1       As her father nears the end of his life, filmm...
# s1006    For Rohan and his magical pal, Keymon, a trip ...
# s1012    This documentary follows three professional vi...
# s102     Under pressure to continue a winning tradition...
# s103     From training to launch to landing, this all-a...
# ...                                                    ...
# s92      This documentary traces the capture of serial ...
# s920     The Son of Sam case grew into a lifelong obses...
# s926     Angelina is crazy about ballet dancing, even t...
# s937     Animals with special powers transform into sup...
# s958     Follow talent management company Pets on Q as ...
#
# [825 rows x 11 columns]

# %%
# filling NULL/NAN with unknown 
netflix_data['cast'].fillna("Unknown", inplace=True)
# check for null values
netflix_data.loc[netflix_data['cast'].isnull()]
# Out:
# Empty DataFrame
# Columns: [type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# 6. Cleaning Directors
# ----

# %%
netflix_data.isna().sum()
# Out:
# type               0
# title              0
# director        2634
# cast               0
# country            0
# date_added         0
# release_year       0
# rating             0
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
# checking for null values
netflix_data.loc[netflix_data['director'].isnull()]
# Out:
#             type                                  title director  \
# show_id
# s100     TV Show                           On the Verge      NaN
# s1004    TV Show                                   Zero      NaN
# s1005    TV Show                     Izzy's Koala World      NaN
# s1006      Movie     Keymon and Nani in Space Adventure      NaN
# s101     TV Show                Tobot Galaxy Detectives      NaN
# ...          ...                                    ...      ...
# s98      TV Show                             Kid Cosmic      NaN
# s99      TV Show              Octonauts: Above & Beyond      NaN
# s994     TV Show                        Shadow and Bone      NaN
# s998     TV Show  Life in Color with David Attenborough      NaN
# s999       Movie                   Searching For Sheela      NaN
#
#                                                       cast  \
# show_id
# s100     Julie Delpy, Elisabeth Shue, Sarah Jones, Alex...
# s1004    Giuseppe Dave Seke, Haroun Fall, Beatrice Gran...
# s1005                           Izzy Bee, Ali Bee, Tim Bee
# s1006                                              Unknown
# s101     Austin Abell, Travis Turner, Cole Howard, Anna...
# ...                                                    ...
# s98      Jack Fisher, Tom Kenny, Amanda C. Miller, Kim ...
# s99      Antonio Aakeel, Chipo Chung, Simon Foster, Ter...
# s994     Jessie Mei Li, Archie Renaux, Ben Barnes, Fred...
# s998                                    David Attenborough
# s999                                       Ma Anand Sheela
#
#                            country         date_added  release_year rating  \
# show_id
# s100         France, United States  September 7, 2021          2021  TV-MA
# s1004                        Italy     April 21, 2021          2021  TV-MA
# s1005                    Australia     April 20, 2021          2021   TV-Y
# s1006                      Unknown     April 20, 2021          2013   TV-Y
# s101                       Unknown  September 7, 2021          2019  TV-Y7
# ...                            ...                ...           ...    ...
# s98                  United States  September 7, 2021          2021  TV-Y7
# s99                 United Kingdom  September 7, 2021          2021   TV-Y
# s994                 United States     April 23, 2021          2021  TV-14
# s998     Australia, United Kingdom     April 22, 2021          2021  TV-PG
# s999                         India     April 22, 2021          2021  TV-14
#
#           duration                                          listed_in  \
# show_id
# s100      1 Season                             TV Comedies, TV Dramas
# s1004     1 Season     International TV Shows, TV Comedies, TV Dramas
# s1005    2 Seasons                                           Kids' TV
# s1006       76 min                 Children & Family Movies, Comedies
# s101     2 Seasons                                           Kids' TV
# ...            ...                                                ...
# s98      2 Seasons         Kids' TV, TV Comedies, TV Sci-Fi & Fantasy
# s99       1 Season                         British TV Shows, Kids' TV
# s994      1 Season  TV Action & Adventure, TV Dramas, TV Sci-Fi & ...
# s998      1 Season  British TV Shows, Docuseries, International TV...
# s999        58 min                Documentaries, International Movies
#
#                                                description
# show_id
# s100     Four women — a chef, a single mom, an heiress ...
# s1004    A shy teen with the power to turn invisible mu...
# s1005    Young koala caretaker Izzy Bee and her family ...
# s1006    For Rohan and his magical pal, Keymon, a trip ...
# s101     An intergalactic device transforms toy cars in...
# ...                                                    ...
# s98      A boy's superhero dreams come true when he fin...
# s99      The Octonauts expand their exploration beyond ...
# s994     Dark forces conspire against orphan mapmaker A...
# s998     Using innovative technology, this docuseries e...
# s999     Journalists and fans await Ma Anand Sheela as ...
#
# [2634 rows x 11 columns]

# %%
# filling NULL/NAN with unknown 
netflix_data['director'].fillna("Unknown", inplace=True)
# check for null values
netflix_data.loc[netflix_data['director'].isnull()]
# Out:
# Empty DataFrame
# Columns: [type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# Check if data is consistent with no NULL/NAN values
# -----

# %%
netflix_data.isna().sum()
# Out:
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %% [markdown]
# 2. FILTER ROWS WHERE A PARTIAL STRING IS PRESENT

# %%
horror_list = netflix_data['listed_in'].str.contains('horror',case=False, na=False)
# netflix_data[horror_list].sample(10)
netflix_data[horror_list]
