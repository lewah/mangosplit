# %%
# packages
import pandas as pd # for data processing
import seaborn as sns # for visualisation 
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
import os

current_directory = os.getcwd()
print("Current Working Directory:", current_directory)
# Out:
# Current Working Directory: /Users/ingridlewah/Desktop/Projects/MANGODEV/mangosplit/Netflix_project

# %%
netflix_data = pd.read_csv("dataset/cleaned_netflix_data.csv")

# %% [markdown]
# 1. WHO ARE THE TOP TEN DIRECTORS WITH THE HIGHEST TV & MOVIES PRODUCED
# -----

# %%
# Find out more about directors , the number of shows(movie $ TV), what did they mostly work on TV or Movie
# netflix_data.head()
# netflix_data['director'].value_counts()
netflix_data[netflix_data['director'] != 'Unknown']['director'].value_counts().head(15)
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Suhas Kadav               16
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Jay Chapman               12
# Youssef Chahine           12
# Steven Spielberg          11
# Don Michael Paul          10
# David Dhawan               9
# Lance Bangs                8
# Kunle Afolayan             8
# Hakan Algül                8
# Name: count, dtype: int64

# %%
netflix_data[netflix_data['director'].isin(['Rajiv Chilaka'])]
# Out:
#        type                                              title       director  \
# 1910  Movie              Chhota Bheem and the Curse of Damyaan  Rajiv Chilaka
# 3412  Movie                       Chhota Bheem - Neeli Pahaadi  Rajiv Chilaka
# 3423  Movie                              Chhota Bheem & Ganesh  Rajiv Chilaka
# 3434  Movie                 Chhota Bheem & Krishna: Mayanagari  Rajiv Chilaka
# 3446  Movie  Chhota Bheem & Krishna: Pataliputra- City of t...  Rajiv Chilaka
# 3457  Movie                 Chhota Bheem And The Broken Amulet  Rajiv Chilaka
# 3468  Movie             Chhota Bheem And The Crown of Valhalla  Rajiv Chilaka
# 3479  Movie               Chhota Bheem and the Incan Adventure  Rajiv Chilaka
# 3490  Movie                Chhota Bheem and The ShiNobi Secret  Rajiv Chilaka
# 3501  Movie                           Chhota Bheem Aur Hanuman  Rajiv Chilaka
# 3512  Movie                           Chhota Bheem aur Krishna  Rajiv Chilaka
# 3523  Movie                Chhota Bheem aur Krishna vs Zimbara  Rajiv Chilaka
# 3557  Movie                      Chhota Bheem: Bheem vs Aliens  Rajiv Chilaka
# 3568  Movie               Chhota Bheem: Dholakpur to Kathmandu  Rajiv Chilaka
# 3590  Movie                     Chhota Bheem: Journey to Petra  Rajiv Chilaka
# 3601  Movie                    Chhota Bheem: Master of Shaolin  Rajiv Chilaka
# 3612  Movie                  Chhota Bheem: The Rise of Kirmada  Rajiv Chilaka
# 5887  Movie                                          Bheemayan  Rajiv Chilaka
# 6274  Movie                              Dragonkala Ka Rahasya  Rajiv Chilaka
#
#                                                    cast  country  \
# 1910  Kaustav Ghosh, Jigna Bhardwaj, Chutki, Rajesh ...    India
# 3412  Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...  Unknown
# 3423  Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...  Unknown
# 3434  Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...  Unknown
# 3446  Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...  Unknown
# 3457  Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...    India
# 3468  Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...  Unknown
# 3479  Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...  Unknown
# 3490  Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...  Unknown
# 3501  Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...  Unknown
# 3512  Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...    India
# 3523  Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...  Unknown
# 3557  Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...  Unknown
# 3568  Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...  Unknown
# 3590  Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...  Unknown
# 3601  Pooja Punabi, Mausam, Julie Tejwani, Rupa Bhim...  Unknown
# 3612  Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig
# 14       Akshay Sanjeev Chavan, Sumit Das
# ...                                   ...
# 8743                          Suhas Kadav
# 8744                          Suhas Kadav
# 8752                         Raja Gosnell
# 8758  Pierre Greco, Nancy Florence Savard
# 8766               Mike Rianda, Jeff Rowe
#
#                                                    cast  \
# 9                                               Unknown
# 10            Sourav Chakraborty, Mayur Vyas, Anil Datt
# 11    Sourav Chakraborty, Vidit Kumar, Mayur Vyas, M...
# 12                        Sourav Chakraborty, Anil Dutt
# 14    Shailendra Pandey, Vinod Kulkarni, Rohan, Muke...
# ...                                                 ...
# 8743  Saurav Chakraborty, Vinod Kulkarni, Mayur Vyas...
# 8744  Saurav Chakraborty, Omee, Sankalp, Rajesh, Vin...
# 8752  Will Arnett, Ludacris, Natasha Lyonne, Stanley...
# 8758  Rachelle Lefevre, Noel Fisher, Colm Feore, Jul...
# 8766  Danny McBride, Abbi Jacobson, Maya Rudolph, Mi...
#
#                             country         date_added  release_year rating  \
# 9                           Unknown     April 20, 2021          2013   TV-Y
# 10                          Unknown     April 20, 2021          2018  TV-Y7
# 11                          Unknown     April 20, 2021          2017   TV-Y
# 12                          Unknown     April 20, 2021          2019   TV-Y
# 14                          Unknown     April 20, 2021          2020  TV-Y7
# ...                             ...                ...           ...    ...
# 8743                        Unknown        May 1, 2021          2014  TV-Y7
# 8744                        Unknown        May 1, 2021          2013  TV-Y7
# 8752  United Kingdom, United States  September 8, 2021          2018     PG
# 8758                         Canada        May 1, 2021          2018  TV-PG
# 8766                        Unknown     April 30, 2021          2021     PG
#
#      duration                           listed_in  \
# 9      76 min  Children & Family Movies, Comedies
# 10     80 min  Children & Family Movies, Comedies
# 11     81 min  Children & Family Movies, Comedies
# 12     84 min            Children & Family Movies
# 14     87 min            Children & Family Movies
# ...       ...                                 ...
# 8743   76 min  Children & Family Movies, Comedies
# 8744   71 min  Children & Family Movies, Comedies
# 8752   90 min  Children & Family Movies, Comedies
# 8758   85 min  Children & Family Movies, Comedies
# 8766  114 min  Children & Family Movies, Comedies
#
#                                             description
# 9     For Rohan and his magical pal, Keymon, a trip ...
# 10    A time machine sends Motu and Patlu back to th...
# 11    While returning a goldfish and an octopus from...
# 12    For Motu, facing off against three children be...
# 14    Kid magician Rudra sets out to save Earth from...
# ...                                                 ...
# 8743  Friends Motu and Patlu get more maritime excit...
# 8744  An otherworldly enemy has been turning the moo...
# 8752  A rough and tough police dog must go undercove...
# 8758  An explorer and a detective set off for the sn...
# 8766  A robot apocalypse put the brakes on their cro...
#
# [641 rows x 11 columns]

# %% [markdown]
# 2. what type of content have they been focussing on over the years?
#
# 2.1 What is the highest number of tv/movies released over the years
#
# -----

# %%
netflix_data['release_year'].value_counts()
# Out:
# release_year
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1925       1
# 1959       1
# 1961       1
# 1947       1
# 1966       1
# Name: count, Length: 74, dtype: int64

# %%
# netflix_data['release_year'].value_counts().plot(kind = 'bar')
yearly_counts = netflix_data.groupby(['release_year', 'type']).size().unstack(fill_value=0)
print(yearly_counts)
# Out:
# type          Movie  TV Show
# release_year
# 1925              0        1
# 1942              2        0
# 1943              3        0
# 1944              3        0
# 1945              3        1
# ...             ...      ...
# 2017            767      265
# 2018            767      380
# 2019            633      397
# 2020            517      436
# 2021            277      315
#
# [74 rows x 2 columns]
