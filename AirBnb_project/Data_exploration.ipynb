# %%
import pandas as pd
import matplotlib
pd.set_option('display.max_columns', None)
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
Airbnb_data = pd.read_csv('Dataset/Kaggle_Airbnb_Open_Data.csv')
Airbnb_data
# Out:
# /var/folders/ll/tr3z9w091y55mt3_qxw9k4gr0000gn/T/ipykernel_95106/4137413238.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   Airbnb_data = pd.read_csv('Dataset/Kaggle_Airbnb_Open_Data.csv')
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# ...

# %%
# finding out the columns in your csv file
Airbnb_data.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
# describe mean,min,max,25%, 50%, 75% etc
Airbnb_data.describe()
# Out:
#                  id       host id            lat           long  \
# count  1.025990e+05  1.025990e+05  102591.000000  102591.000000
# mean   2.914623e+07  4.925411e+10      40.728094     -73.949644
# std    1.625751e+07  2.853900e+10       0.055857       0.049521
# min    1.001254e+06  1.236005e+08      40.499790     -74.249840
# 25%    1.508581e+07  2.458333e+10      40.688740     -73.982580
# 50%    2.913660e+07  4.911774e+10      40.722290     -73.954440
# 75%    4.320120e+07  7.399650e+10      40.762760     -73.932350
# max    5.736742e+07  9.876313e+10      40.916970     -73.705220
#
#        Construction year  minimum nights  number of reviews  \
# count      102385.000000   102190.000000      102416.000000
# mean         2012.487464        8.135845          27.483743
# std             5.765556       30.553781          49.508954
# min          2003.000000    -1223.000000           0.000000
# 25%          2007.000000        2.000000           1.000000
# ...

# %%
# Find the data types of your table "Airbnb_data"
Airbnb_data.dtypes
# Out:
# id                                  int64
# NAME                               object
# host id                             int64
# host_identity_verified             object
# host name                          object
# neighbourhood group                object
# neighbourhood                      object
# lat                               float64
# long                              float64
# country                            object
# country code                       object
# instant_bookable                   object
# cancellation_policy                object
# room type                          object
# Construction year                 float64
# price                              object
# service fee                        object
# minimum nights                    float64
# number of reviews                 float64
# last review                        object
# reviews per month                 float64
# review rate number                float64
# ...

# %%
# Finding the number of NULL values in @ column
# finding if you have any missing values
Airbnb_data.isna().sum()
# Out:
# id                                     0
# NAME                                 250
# host id                                0
# host_identity_verified               289
# host name                            406
# neighbourhood group                   29
# neighbourhood                         16
# lat                                    8
# long                                   8
# country                              532
# country code                         131
# instant_bookable                     105
# cancellation_policy                   76
# room type                              0
# Construction year                    214
# price                                247
# service fee                          273
# minimum nights                       409
# number of reviews                    183
# last review                        15893
# reviews per month                  15879
# review rate number                   326
# calculated host listings count       319
# ...

# %%
Airbnb_data_subset = Airbnb_data [['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
       'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
       'country code', 'instant_bookable', 'cancellation_policy', 'room type',
       'Construction year', 'price', 'service fee', 'minimum nights',
       'number of reviews', 'last review', 'reviews per month',
       'review rate number', 'calculated host listings count',
       'availability 365', 'house_rules', 'license']]

# %%
# Finding the number of NULL values in @ column
# finding if you have any missing values
Airbnb_data_subset.isna().sum()
# Out:
# id                                     0
# NAME                                 250
# host id                                0
# host_identity_verified               289
# host name                            406
# neighbourhood group                   29
# neighbourhood                         16
# lat                                    8
# long                                   8
# country                              532
# country code                         131
# instant_bookable                     105
# cancellation_policy                   76
# room type                              0
# Construction year                    214
# price                                247
# service fee                          273
# minimum nights                       409
# number of reviews                    183
# last review                        15893
# reviews per month                  15879
# review rate number                   326
# calculated host listings count       319
# ...

# %%
# finding the data types of the columns
Airbnb_data_subset.dtypes
# Out:
# id                                  int64
# NAME                               object
# host id                             int64
# host_identity_verified             object
# host name                          object
# neighbourhood group                object
# neighbourhood                      object
# lat                               float64
# long                              float64
# country                            object
# country code                       object
# instant_bookable                   object
# cancellation_policy                object
# room type                          object
# Construction year                 float64
# price                              object
# service fee                        object
# minimum nights                    float64
# number of reviews                 float64
# last review                        object
# reviews per month                 float64
# review rate number                float64
# ...

# %%
# describe mean,min,max,25%, 50%, 75% etc
Airbnb_data_subset.describe()
# Out:
#                  id       host id            lat           long  \
# count  1.025990e+05  1.025990e+05  102591.000000  102591.000000
# mean   2.914623e+07  4.925411e+10      40.728094     -73.949644
# std    1.625751e+07  2.853900e+10       0.055857       0.049521
# min    1.001254e+06  1.236005e+08      40.499790     -74.249840
# 25%    1.508581e+07  2.458333e+10      40.688740     -73.982580
# 50%    2.913660e+07  4.911774e+10      40.722290     -73.954440
# 75%    4.320120e+07  7.399650e+10      40.762760     -73.932350
# max    5.736742e+07  9.876313e+10      40.916970     -73.705220
#
#        Construction year  minimum nights  number of reviews  \
# count      102385.000000   102190.000000      102416.000000
# mean         2012.487464        8.135845          27.483743
# std             5.765556       30.553781          49.508954
# min          2003.000000    -1223.000000           0.000000
# 25%          2007.000000        2.000000           1.000000
# ...

# %%
# histogram visualization of .describe()
Airbnb_data_subset.hist(bins=60)
# Out:
# array([[<Axes: title={'center': 'id'}>,
#         <Axes: title={'center': 'host id'}>,
#         <Axes: title={'center': 'lat'}>],
#        [<Axes: title={'center': 'long'}>,
#         <Axes: title={'center': 'Construction year'}>,
#         <Axes: title={'center': 'minimum nights'}>],
#        [<Axes: title={'center': 'number of reviews'}>,
#         <Axes: title={'center': 'reviews per month'}>,
#         <Axes: title={'center': 'review rate number'}>],
#        [<Axes: title={'center': 'calculated host listings count'}>,
#         <Axes: title={'center': 'availability 365'}>, <Axes: >]],
#       dtype=object)

# %%
Airbnb_data_subset.hist(bins=60, figsize=(20,10))
# Out:
# array([[<Axes: title={'center': 'id'}>,
#         <Axes: title={'center': 'host id'}>,
#         <Axes: title={'center': 'lat'}>],
#        [<Axes: title={'center': 'long'}>,
#         <Axes: title={'center': 'Construction year'}>,
#         <Axes: title={'center': 'minimum nights'}>],
#        [<Axes: title={'center': 'number of reviews'}>,
#         <Axes: title={'center': 'reviews per month'}>,
#         <Axes: title={'center': 'review rate number'}>],
#        [<Axes: title={'center': 'calculated host listings count'}>,
#         <Axes: title={'center': 'availability 365'}>, <Axes: >]],
#       dtype=object)

# %%
# finding is null values in a table based on a column
Airbnb_data_subset[Airbnb_data_subset['NAME'].isna()]
# Out:
#               id NAME      host id host_identity_verified  host name  \
# 3        1002755  NaN  85098326012            unconfirmed      Garry
# 57       1032817  NaN  18424415847            unconfirmed     Carina
# 58       1033369  NaN  48877238684                    NaN     Sophia
# 59       1033922  NaN  71987706184               verified      Rosie
# 60       1034474  NaN  85649449746               verified  Frederick
# ...          ...  ...          ...                    ...        ...
# 100074  56272206  NaN  19395911932            unconfirmed       Alex
# 100085  56278282  NaN  24411362869            unconfirmed     Elisia
# 100294  56393712  NaN  87823753249               verified     Irisha
# 100312  56403654  NaN  36683367732               verified       Emmy
# 100354  56426850  NaN  33931743606            unconfirmed     Nimrod
#
#        neighbourhood group    neighbourhood       lat      long  \
# 3                 Brooklyn     Clinton Hill  40.68514 -73.95976
# ...

# %%
# find value of listings with review rate above 4
Airbnb_data_subset[Airbnb_data_subset['review rate number'] > 4]
# Out:
#              id                                          NAME      host id  \
# 2       1002403           THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 6       1004650                               BlissArtsSpace!  61300605564
# 7       1005202                               BlissArtsSpace!  90821839709
# 9       1006307            Cozy Clean Guest Room - Family Apt  75527839483
# 17      1010725             Perfect for Your Parents + Garden  80380130347
# ...         ...                                           ...          ...
# 102581  6085258  Bright Bedroom in Bustling Bed Stuy Brooklyn  17339949163
# 102585  6087467           Williamsburg family home -3 bedroom  23540078751
# 102586  6088019                Patio Oasis in Upper East Side  41141109074
# 102591  6090781            Columbus Ave Apt 1 block from Park  50908010324
# 102596  6093542                Comfy, bright room in Brooklyn  69050334417
#
#        host_identity_verified host name neighbourhood group  \
# ...

# %%
Four_above = Airbnb_data_subset[Airbnb_data_subset['review rate number'] > 4]
Four_above[['id','review rate number']].plot()
# Out:
# <Axes: >

# %%
Four_above[['id','review rate number']].plot(kind='scatter',x='id', y='review rate number')
# Out:
# <Axes: xlabel='id', ylabel='review rate number'>

# %%
Airbnb_data_subset[['neighbourhood','review rate number']].plot(kind='scatter',x='neighbourhood', y='review rate number')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 Airbnb_data_subset[['neighbourhood','review rate number']].plot(kind='scatter',x='neighbourhood', y='review rate number')
#
# File ~/opt/anaconda3/envs/AirBnb/lib/python3.11/site-packages/pandas/plotting/_core.py:945, in PlotAccessor.__call__(self, *args, **kwargs)
#     943 if kind in self._dataframe_kinds:
#     944     if isinstance(data, ABCDataFrame):
# --> 945         return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     946     else:
#     947         raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# File ~/opt/anaconda3/envs/AirBnb/lib/python3.11/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ...

# %%
# Find the values in neighbourhood and how many times they appear

Airbnb_data_subset['neighbourhood'].value_counts()

# x = Airbnb_data_subset['neighbourhood'].value_counts()
# print(x)
# Out:
# Bedford-Stuyvesant        7937
# Williamsburg              7775
# Harlem                    5466
# Bushwick                  4982
# Hell's Kitchen            3965
#                           ...
# Rossville                    3
# Lighthouse Hill              3
# Fort Wadsworth               2
# Glen Oaks                    2
# Chelsea, Staten Island       1
# Name: neighbourhood, Length: 224, dtype: int64

# %%
pd.DataFrame(Airbnb_data_subset['neighbourhood'].value_counts()).plot(kind='bar', figsize=(20,10))

# %%
Airbnb_data_subset.apply(pd.Series.value_counts)
